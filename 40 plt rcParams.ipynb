# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['FangSong'] #字体
plt.rcParams['font.size'] = 20 #字体大小
plt.rcParams['lines.linewidth'] = 2 # 宽度
plt.rcParams['axes.prop_cycle'] = plt.cycler('color',['r','y']) # 默认颜色顺序

# %%
plt.plot(range(0,20))
plt.plot(range(0,20,2))
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %%
# name.mplstyle 创建此配置文件

# mpl.get_configdir() 找到配置文件的路径

# stylelib - 创建此文件夹并将配置文件放进去

# plt.style.use("name") # 然后调用配置文件
