# %%
#线性回归绘图
#implot - x，y是字符串 regplot - 比较灵活
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
#sns.lmplot(x="total_bill",y="tip",data = tips)
sns.regplot(x="total_bill",y="tip",data = tips) # x = tips['total_bill'], y = tips['tip']

# order - 回归的多项式次数
# robust - 忽略噪音点
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
